# %% [markdown]
# # Day1

# %% [markdown]
# Variables and operators

# %%
print("this is ram here")
# Out:
# this is ram here

# %%
print(2+2)
# Out:
# 4

# %%
a=10
print(a)
# Out:
# 10

# %%
a=b=c="ram"
print(a)
print(b)
print(c)
# Out:
# ram
# ram
# ram

# %%
a,b,c="ram","shyam","ashok"
print(a)
print(b)
print(c)
# Out:
# ram
# shyam
# ashok

# %% [markdown]
# # operators

# %%
a=10
b=10
print(a+b)
# Out:
# 20

# %%
a=10
b=10
print(a-b)
# Out:
# 0

# %%
a=10
b=10
print(a*b)
# Out:
# 100

# %%
a=2+5j
b=4
print(a+b)
# Out:
# (6+5j)

# %%
a=2+5j
b=4
print(a-b)
print(type(a))
# Out:
# (-2+5j)
# <class 'complex'>

# %%
a= 10
b= 50
print(a < b)
# Out:
# True

# %%
a=[1,2,3,4,5]
print(a)
print(type(a))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
a=(1,2,3,4,5)
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
import numpy as np
a = np.arange(10)
print(a[2:5])
# Out:
# [2 3 4]

# %%
a = np.array([[1, 2], [3, 4]])
print(a.ndim)
# Out:
# 2

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = a + b
print(c)
# Out:
# [5 7 9]

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = np.concatenate((a, b))
print(c)
# Out:
# [1 2 3 4 5 6]

# %%
a = np.array([[1,2,3],[4,5,6]])
a[1,2]
# Out:
# 6

# %%
print(np.zeros(5).dtype)
# Out:
# float64

# %%
arr = np.array([[1,2,3],[4,5,6]]) 
np.hstack((arr,arr))
# Out:
# array([[1, 2, 3, 1, 2, 3],
#        [4, 5, 6, 4, 5, 6]])

# %%
a = np.array([1,2,3]) 
print(a)
# Out:
# [1 2 3]

# %%
import pandas as pnd
pnd.Series([1,2], index= ['a','b','c'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 import pandas as pnd
# ----> 2 pnd.Series([1,2], index= ['a','b','c'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:461, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     459     index = default_index(len(data))
#     460 elif is_list_like(data):
# --> 461     com.require_length_match(data, index)
#     463 # create/copy the manager
#     464 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
# ...

# %%
import pandas as pd
s =pd.Series([1,2,3,4,5],index= ['a','b','c','d','e'])
print(s['f'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
Import pandas as pd
Import numpy as np  
df = pd.DataFrame(np.array([[4,6,9],[5,1,3]]))
print(df.shape)
# Out:
#   Cell In[18], line 1
#     Import pandas as pd
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.read_csv('Shark_Tank.csv')
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.head(10)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
# 5               2             6         Agro tourism
# 6               3             7          Qzense Labs
# 7               3             8            Peeschute
# 8               3             9                 NOCD
# 9               4            10                Cosiq
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# ...

# %%
df.tail(8)
# Out:
#      episode_number  pitch_number          brand_name  \
# 109              33           110              Proxgy
# 110              34           111  Nomad Food Project
# 111              34           112         Twee in One
# 112              34           113       Green Protein
# 113              34           114             On2Cook
# 114              35           115       Jain Shikanji
# 115              35           116               Woloo
# 116              35           117        Elcare India
#
#                                     idea  deal  pitcher_ask_amount  \
# 109                                   VR     1                35.0
# 110                           Bacon Jams     1                40.0
# 111  Reversible and convertible clothing     0                30.0
# 112                  Plant-Based Protein     0                60.0
# 113               Fastest Cooking Device     0               100.0
# 114                             Lemonade     1                40.0
# ...

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#               brand_name                                           idea
# 0    BluePine Industries                                   Frozen Momos
# 1          Booz scooters  Renting e-bike for mobility in private spaces
# 2    Heart up my Sleeves                             Detachable Sleeves
# 3             Tagz Foods                           Healthy Potato Chips
# 4         Head and Heart                       Brain Development Course
# ..                   ...                                            ...
# 112        Green Protein                            Plant-Based Protein
# 113              On2Cook                         Fastest Cooking Device
# 114        Jain Shikanji                                       Lemonade
# 115                Woloo                                Washroom Finder
# 116         Elcare India                           Carenting for Elders
#
# [117 rows x 2 columns]

# %%
df[["episode_number","brand_name"]]
# Out:
#      episode_number           brand_name
# 0                 1  BluePine Industries
# 1                 1        Booz scooters
# 2                 1  Heart up my Sleeves
# 3                 2           Tagz Foods
# 4                 2       Head and Heart
# ..              ...                  ...
# 112              34        Green Protein
# 113              34              On2Cook
# 114              35        Jain Shikanji
# 115              35                Woloo
# 116              35         Elcare India
#
# [117 rows x 2 columns]

# %%
df["brand_name"]
# Out:
# 0      BluePine Industries
# 1            Booz scooters
# 2      Heart up my Sleeves
# 3               Tagz Foods
# 4           Head and Heart
#               ...
# 112          Green Protein
# 113                On2Cook
# 114          Jain Shikanji
# 115                  Woloo
# 116           Elcare India
# Name: brand_name, Length: 117, dtype: object

# %%
df.insert(loc = 3,column="food", value="bread")

# %%
df
# Out:
#      episode_number  pitch_number           brand_name   food  \
# 0                 1             1  BluePine Industries  bread
# 1                 1             2        Booz scooters  bread
# 2                 1             3  Heart up my Sleeves  bread
# 3                 2             4           Tagz Foods  bread
# 4                 2             5       Head and Heart  bread
# ..              ...           ...                  ...    ...
# 112              34           113        Green Protein  bread
# 113              34           114              On2Cook  bread
# 114              35           115        Jain Shikanji  bread
# 115              35           116                Woloo  bread
# 116              35           117         Elcare India  bread
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# ...

# %%
df.insert(3,"ram",23)

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  ram   food  \
# 0                 1             1  BluePine Industries   23  bread
# 1                 1             2        Booz scooters   23  bread
# 2                 1             3  Heart up my Sleeves   23  bread
# 3                 2             4           Tagz Foods   23  bread
# 4                 2             5       Head and Heart   23  bread
# ..              ...           ...                  ...  ...    ...
# 112              34           113        Green Protein   23  bread
# 113              34           114              On2Cook   23  bread
# 114              35           115        Jain Shikanji   23  bread
# 115              35           116                Woloo   23  bread
# 116              35           117         Elcare India   23  bread
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# ...

# %%
df["ashok"] = 25

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  ram   food  \
# 0                 1             1  BluePine Industries   23  bread
# 1                 1             2        Booz scooters   23  bread
# 2                 1             3  Heart up my Sleeves   23  bread
# 3                 2             4           Tagz Foods   23  bread
# 4                 2             5       Head and Heart   23  bread
# ..              ...           ...                  ...  ...    ...
# 112              34           113        Green Protein   23  bread
# 113              34           114              On2Cook   23  bread
# 114              35           115        Jain Shikanji   23  bread
# 115              35           116                Woloo   23  bread
# 116              35           117         Elcare India   23  bread
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# ...
